# %% [markdown]
# # Airflow DAGs 101

# %% [markdown]
# ## I. Define your DAG

# %% [markdown]
# #### 1. Set up your Astro Project

# %%
mkdir ca-demo-DAGs101

# %% [markdown]
# #### 2. Switch to that created folder

# %%
cd ca-demo-DAGs101

# %% [markdown]
# #### 3. Initialize your project

# %%
astro dev init

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 4. Create a new DAG
#
# Go to dags folder, create a new python file (ca_dag001.py)
#
# * Import statements
# * Define your DAG object
# * Create your Tasks (check https://registry.astronomer.io/)
# * Define the order of tasks executions and their dependencies

# %% [markdown]
# #### 5. Run your DAG

# %%
astro dev start

# %% [markdown]
# First Order

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Second Order

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 6. Create a second DAG

# %% [markdown]
# #### 7. Stop your DAGs

# %%
astro dev stop
