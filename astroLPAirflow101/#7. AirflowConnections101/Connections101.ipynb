# %% [markdown]
# # Connections 101

# %% [markdown]
# ## 1. Create a connection

# %% [markdown]
# To Create a connection, go to your Airflow UI -> Admin -> Connections -> + Button

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2. Connection Parameters

# %% [markdown]
# Check the link: https://registry.astronomer.io/
#
# Search for HTTP, and select the corresponding provider, then select the operator (https://registry.astronomer.io/providers/apache-airflow-providers-http/versions/4.13.1/modules/HttpOperator)

# %% [markdown]
# ## 3. Interact with Snowflake

# %% [markdown]
# a. Create a pipeline (See ca_dag_snowflake.py)

# %% [markdown]
# b. Create your Snowflake Connection (.env file)
#
# * Go to the .env file in your project directory
# * Add AIRFLOW_CONN_SNOWFLAKE parameters

# %%
c. Add packages to Requirements.

Add the following

apache-airflow-providers-snowflake==5.7.0
apache-airflow-providers-common-sql==1.16.0

to requirements.txt
